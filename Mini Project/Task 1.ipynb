# %%
import pandas as pd
df_activities=pd.read_csv("C:/Users/99263/Downloads/cardioActivities.csv")
df_activities.sample(3)
# Out:
#                     Date                           Activity Id     Type  \
# 224  2016-04-11 18:25:11  f5856eb2-a21b-4796-9b0c-b581bfb0f777  Running
# 342  2014-10-20 18:10:00  bc53fc84-3a38-4dca-bfb9-0fa3548ec398  Running
# 248  2015-09-24 18:28:14  949d5983-73ea-4a25-a589-87e0280b1b8e  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 224        NaN           8.88    47:00         5:17                 11.34
# 342        NaN           9.61    51:17         5:20                 11.25
# 248        NaN           9.43    51:16         5:26                 11.03
#
#      Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 224            616.0         83                     143.0              NaN
# 342            672.0         54                       NaN              NaN
# 248            650.0         77                     138.0              NaN
#
#                      Notes               GPX File
# ...
